# %% [markdown]
# 1. Here is a sample line of code that can be executed in Python:
#    print("Hello, World!")

# %%
word = "Hello, World!"
print(word)
# Out:
# Hello, World!

# %% [markdown]
#         IF ELSE
# 2. Given an integer,n, perform the following conditional actions:
#     If  is odd, print Weird
#     If  is even and in the inclusive range of 2 to 5, print Not Weird
#     If  is even and in the inclusive range of 6 to 20, print Weird
#     If  is even and greater than , print Not Weird

# %%
n = int(input())
if (n % 2 != 0):
    print("Weird")
elif 2 <= n <= 5:
    print("Not Weird")
elif 6 <= n <=20:
    print("Weird")
else:
    print("Not Weird")
# Out:
#  24
# Not Weird

# %% [markdown]
#             Arthemtic  operation
# 3. The provided code stub reads two integers from STDIN, a and b. Add code to print three lines where:
#    The first line contains the sum of the two numbers.
#    The second line contains the difference of the two numbers (first - second).
#    The third line contains the product of the two numbers.

# %%
a = 2
b = 4
print("The sum of the two numbers = ", a + b)
print("The difference of the two numbers = ", a - b)
print("The product of the two numbers = ", a * b)
# Out:
# The sum of the two numbers =  6
# The difference of the two numbers =  -2
# The product of the two numbers =  8

# %% [markdown]
#         Division
# 4. The provided code stub reads two integers, a andb , from STDIN.
#    Add logic to print two lines. The first line should contain the result of integer division,  a // b .The second line should contain the result of float division,  a/b .
#    No rounding or formatting is necessary.

# %%
a = int(input())
b = int(input())
print("The result of integer division = ", a//b)
print("The result offloat division = ", a/b)
# Out:
#  6
#  5
# The result of integer division =  1
# The result offloat division =  1.2

# %% [markdown]
#         LOOPS
# 5. The provided code stub reads an integer,n , from STDIN. For all non-negative integers i < n , print i (square) .

# %%
n = int(input())
for i in range(n):
    print(i * i)
# Out:
#  5
# 0
# 1
# 4
# 9
# 16

# %% [markdown]
#             Write a function
# 6. An extra day is added to the calendar almost every four years as February 29, and the day is called a leap day. It corrects the calendar for the fact that our planet takes approximately 365.25 days to orbit the sun. A leap year contains a leap day.
#
#     In the Gregorian calendar, three conditions are used to identify leap years:
#     The year can be evenly divided by 4, is a leap year, unless:
#     The year can be evenly divided by 100, it is NOT a leap year, unless:
#     The year is also evenly divisible by 400. Then it is a leap year.
#     This means that in the Gregorian calendar, the years 2000 and 2400 are leap years, while 1800, 1900, 2100, 2200, 2300 and 2500 are NOT leap years. Source
#
# Task
#
#     Given a year, determine whether it is a leap year. If it is a leap year, return the Boolean True, otherwise return False.
#     Note that the code stub provided reads from STDIN and passes arguments to the is_leap function. It is only necessary to complete the is_leap function.

# %%
def is_leap(year):
    leap = False
    if year % 400 == 0:
        leap = True
    elif year % 100 == 0:
        leap = False
    elif year % 4 == 0:
        leap = True
    return leap
year = int(input())
print(is_leap(year))
# Out:
#  2000
# True

# %% [markdown]
#             print function
# 7. The included code stub will read an integer, n , from STDIN.
#
# Without using any string methods, try to print the following:
# 123...n
#
# Note that "..." represents the consecutive values in between.

# %%
n = int(input())
for i in range(1, n+1):
    print(i, end = "")
# Out:
#  8
# 12345678
